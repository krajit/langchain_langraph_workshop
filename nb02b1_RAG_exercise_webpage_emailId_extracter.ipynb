# %% [markdown]
# # Example : Extract email address from a webpage
#
# Lets extract information from webpages - using Unstructured
#
# https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#overview

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_unstructured import UnstructuredLoader

loader = UnstructuredLoader(web_url="https://maths.du.ac.in/faculty-profile/")
docs = loader.load()

# %%
full_doc = "\n\n".join(doc.page_content for doc in docs)
print(full_doc)
# Out:
# DU
#
#
#
#
#
# Menu Close
#
# Home
#
# About
#
# Welcome
#
# History
#
# Campus
#
# Seminar & Lecture Rooms
#
# Research Scholar Room
#
# Computer Lab
#
# Committee Room
#
# Library
#
# Disabled-Friendly Campus
#
# Clean and Green Campus
#
# Ranking
#
# Committees
#
# Accomplishments
#
# Department
#
# Faculty
#
# Students
#
# Annual Reports
#
# Gallery
#
# Redressal Mechanisms
#
# Brochure
#
# Contact Us
#
# People
#
# Faculty Profile
#
# Post-Doc Fellows
#
# Ph.D. Scholars
#
# M.Phil. Scholars
#
# Supporting Staff
#
# Tutors
#
# Former Faculty
#
# Former HODs
#
# Research
#
# Research Areas
#
# Publications
#
# Books Authored
#
# Research Grants
#
# Collaborations
#
# Research Supervision
#
# M.Phil. Awarded
#
# Ph.D. Awarded
#
# Academics
#
# M.Sc. Programme
#
# Ph.D. Programme
#
# U.G. Curriculum
#
# Academic Calendar
#
# Time Tables
#
# Examination and Results
#
# Admissions
#
# M.Sc. Admissions
#
# Ph.D. Admissions
#
# Resources
#
# Library@DU
#
# Forms
#
# Useful Links
#
# Previous Year Papers
#
# News & Events @ Outside DU
#
# Opportunities
#
# Placement
#
# Scholarships/Fellowships/Internships
#
# Ad-hoc Panel
#
# Events
#
# Ph.D. Seminars
#
# Colloquia/Workshops
#
# Co-Curricular Activities
#
# Alumni
#
# Archives
#
# Notices (2017-24)
#
# Publications (2015-20)
#
# Ad-hoc Panel (2016-19)
#
# M.Phil. Scholars (2010-17)
#
# Ph.D. Scholars (2013-20)
#
# M.Phil./Ph.D. Seminars (2014-20)
#
# Home
#
# About
#
# Welcome
#
# History
#
# Campus
#
# Seminar & Lecture Rooms
#
# Research Scholar Room
#
# Computer Lab
#
# Committee Room
#
# Library
#
# Disabled-Friendly Campus
#
# Clean and Green Campus
#
# Ranking
#
# Committees
#
# Accomplishments
#
# Department
#
# Faculty
#
# Students
#
# Annual Reports
#
# Gallery
#
# Redressal Mechanisms
#
# Brochure
#
# Contact Us
#
# People
#
# Faculty Profile
#
# Post-Doc Fellows
#
# Ph.D. Scholars
#
# M.Phil. Scholars
#
# Supporting Staff
#
# Tutors
#
# Former Faculty
#
# Former HODs
#
# Research
#
# Research Areas
#
# Publications
#
# Books Authored
#
# Research Grants
#
# Collaborations
#
# Research Supervision
#
# M.Phil. Awarded
#
# Ph.D. Awarded
#
# Academics
#
# M.Sc. Programme
#
# Ph.D. Programme
#
# U.G. Curriculum
#
# Academic Calendar
#
# Time Tables
#
# Examination and Results
#
# Admissions
#
# M.Sc. Admissions
#
# Ph.D. Admissions
#
# Resources
#
# Library@DU
#
# Forms
#
# Useful Links
#
# Previous Year Papers
#
# News & Events @ Outside DU
#
# Opportunities
#
# Placement
#
# Scholarships/Fellowships/Internships
#
# Ad-hoc Panel
#
# Events
#
# Ph.D. Seminars
#
# Colloquia/Workshops
#
# Co-Curricular Activities
#
# Alumni
#
# Archives
#
# Notices (2017-24)
#
# Publications (2015-20)
#
# Ad-hoc Panel (2016-19)
#
# M.Phil. Scholars (2010-17)
#
# Ph.D. Scholars (2013-20)
#
# M.Phil./Ph.D. Seminars (2014-20)
#
# Faculty Profile
#
# Post-Doc Fellows
#
# Ph.D. Scholars
#
# M.Phil. Scholars
#
# Supporting Staff
#
# Tutors
#
# Former Faculty
#
# Former HODs
#
#
#
# Name: Prof. Tarun Kumar Das Education: Ph.D., University of Allahabad Designation: Professor & Head (Formerly: Registrar, University of Delhi) Research Area: Dynamical Systems, Ergodic Theory, Topology Office: Room No. 5 Email: tarukd@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Prof. C.S. Lalitha Education: Ph.D., University of Delhi Designation: Senior Professor (South Campus) Research Area: Optimization, Mathematical Programming Office: Room No. 306 Email: cslalitha1@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Prof. Ruchi Das Education: Ph.D., The M.S. University of Baroda & Post-Doc., University of Athens, Greece Designation: Professor Research Area: Dynamical Systems, Topology Office: Room No. 7 Email: rdasmsu@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Prof. Vusala Ambethkar Education: Ph.D., Osmania University Designation: Professor Research Area: Fluid Mechanics, Heat and Mass Transfer, Numerics of PDEs, Conservation Laws Office: Room No. 109 Email: vambethkar@gmail.com, vambethkar@maths.du.ac.in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Prof. Sachi Srivastava Education: Ph.D., Oxford University & Post-Doc., IISc. Bangalore Designation: Professor (South Campus) Research Area: Functional Analysis, Operator Semigroups, Abstract Evolution Equations Office: Room No. 304 Email: sachi_srivastava@yahoo.com; ssrivastava@maths.du.ac.in Homepage: https://sites.google.com/view/sachisrivastava/home
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Prof. Lalit Kumar Education: Ph.D., University of Delhi Designation: Professor Research Area: Functional Analysis, Frame Theory Office: Room No. 11 Email: lalit@maths.du.ac.in, lkumarvashisht@gmail.com Homepage: https://sites.google.com/site/lalitkvashisht/
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Prof. Arvind Patel Education: Ph.D., DDU Gorakhpur University Designation: Professor Research Area: Fluid Dynamics, Partial Differential Equations Office: Room No. 14 Email: arvindpatelmath09@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Atul Gaur Education: Ph.D., IIT Kanpur Designation: Associate Professor Research Area: Commutative Algebra Office: Room No. 110 Email: agaur@maths.du.ac.in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Hemant Kumar Singh Education: Ph.D., University of Delhi Designation: Associate Professor Research Area: Algebraic Topology Office: Room No. 10 Email: hksinghdu@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Ranjana Jain Education: Ph.D., University of Delhi Designation: Associate Professor Research Area: Functional Analysis, Operator Algebra Office: Room No. 112 Email: rjain@maths.du.ac.in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Sachin Kumar Education: Ph.D., IIT Roorkee Designation: Associate Professor Research Area: Nonlinear Partial Differential Equations, Nonlinear Evolution Equations, Mathematical Modeling and General Relativity Office: Room No. 12 Email: sachinambariya@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Ratikanta Panda Education: Ph.D., IISc. Bangalore Designation: Assistant Professor Research Area: Analysis of PDEs, Nonlinear Functional Analysis Office: Room No. 4 Email: rkpanda@maths.du.ac.in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. A. Zothansanga Education: Ph.D., University of Delhi Designation: Assistant Professor (South Campus) Research Area: Functional Analysis, Hilbert and Boas Transform Office: Room No. 307 Email: azothansanga26@yahoo.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Anupama Panigrahi Education: Ph.D., HRI Allahabad Designation: Assistant Professor (South Campus) Research Area: Number Theory, Cryptography Office: Room No. 312 Email: anupama.panigrahi@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Anuj Bishnoi Education: Ph.D., Panjab University Designation: Assistant Professor Research Area: Algebraic Number Theory, Valuation Theory Office: Room No. 6 Email: anuj.bshn@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Pratima Rai Education: Ph.D., Panjab University Designation: Assistant Professor Research Area: Numerical Analysis, Computational ODEs and PDEs, Singular Perturbation Problems, Finite Difference Schemes, Finite Element Schemes Office: Room No. 3 Email: pratimarai5@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Surendra Kumar Education: Ph.D., IIT Roorkee Designation: Assistant Professor Research Area: Nonlinear Analysis, Functional Differential Equations, Control Theory, Stochastic Analysis Office: Room No. 110A Email: surendraiitr8@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Randheer Singh Education: Ph.D., University of Delhi Designation: Assistant Professor Research Area: Partial Differential Equations, Nonlinear Waves Office: Room No. 2 Email: randheernsit@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Sumit Nagpal Education: Ph.D., University of Delhi Designation: Assistant Professor Research Area: Complex Analysis, Geometric Function Theory Office: Room No. 1 Email: sumitnagpal.du@gmail.com Homepage: https://sites.google.com/view/dr-sumit-nagpal-du
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Dr. Mrigendra Singh Kushwaha Education: Ph.D., IMSc. Chennai & Post-Doc., IISc. Bangalore Designation: Assistant Professor Research Area: Representation Theory of Lie Algebras Office: Room No. 1 Email: mrigendra154@gmail.com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Name: Prof. Ajay Kumar, FNASc Education: Ph.D., University of Delhi Designation: Senior Scientist, National Academy of Sciences, India Research Area: Operator Algebras, Harmonic Analysis, Complex Analysis, Operator Spaces Office: Room No. 13 Email: akumar@maths.du.ac.in Homepage: https://sites.google.com/view/ajay-kumar/home
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Department of Mathematics
#
# Faculty of Mathematical Sciences Guru Tegh Bahadur Road, University of Delhi, Delhi 110 007, India
#
# head@maths.du.ac.in
#
# +91-11-27666658
#
# Quick Links
#
# Menu Close
#
# Academic Calendar
#
# Ad-hoc Panel
#
# Committees
#
# Examination and Results
#
# Forms
#
# List of Holidays
#
# Academic Calendar
#
# Ad-hoc Panel
#
# Committees
#
# Examination and Results
#
# Forms
#
# List of Holidays
#
# Quick Links
#
# Menu Close
#
# M.Sc. Programme
#
# Ph.D. Programme
#
# Placement
#
# Redressal Mechanisms
#
# U.G. Curriculum
#
# Useful Links
#
# M.Sc. Programme
#
# Ph.D. Programme
#
# Placement
#
# Redressal Mechanisms
#
# U.G. Curriculum
#
# Useful Links
#
# ©2024 Department of Mathematics, University of Delhi
#
# Scroll to Top

# %% [markdown]
# ## No need for chunking and splitted
#
# Since this is very small page, we can pass the content of the entire page as a context. No need to splitting and rerieval in this case.

# %%
#question = "Tell me about Randheer Singh?"
question = "Make a list of all email address."

# %%
# RAG promt template
prompt_template = """You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
Question: {question} 
Context: {context} 
Answer:"""

# make the LLM read see the prompt, and analyse the retrieved document, and generate response

from langchain.chat_models import init_chat_model
llm = init_chat_model("gpt-4o-mini", model_provider="openai")

response = llm.invoke(prompt_template.format(
    context=full_doc,
    question=question))
    
print(response.content)
# Out:
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here are the email addresses from the provided context:
#
# 1. tarukd@gmail.com
# 2. cslalitha1@gmail.com
# 3. rdasmsu@gmail.com
# 4. vambethkar@gmail.com
# 5. vambethkar@maths.du.ac.in
# 6. sachi_srivastava@yahoo.com
# 7. ssrivastava@maths.du.ac.in
# 8. lalit@maths.du.ac.in
# 9. lkumarvashisht@gmail.com
# 10. arvindpatelmath09@gmail.com
# 11. agaur@maths.du.ac.in
# 12. hksinghdu@gmail.com
# 13. rjain@maths.du.ac.in
# 14. sachinambariya@gmail.com
# 15. rkpanda@maths.du.ac.in
# 16. azothansanga26@yahoo.com
# 17. anupama.panigrahi@gmail.com
# 18. anuj.bshn@gmail.com
# 19. pratimarai5@gmail.com
# 20. surendraiitr8@gmail.com
# 21. randheernsit@gmail.com
# 22. sumitnagpal.du@gmail.com
# 23. mrigendra154@gmail.com
# 24. akumar@maths.du.ac.in
# 25. head@maths.du.ac.in

# %%
from IPython.display import Markdown
Markdown(response.content)
# Out:
# Here is a list of email addresses from the provided context:
#
# 1. tarukd@gmail.com
# 2. cslalitha1@gmail.com
# 3. rdasmsu@gmail.com
# 4. vambethkar@gmail.com
# 5. vambethkar@maths.du.ac.in
# 6. sachi_srivastava@yahoo.com
# 7. ssrivastava@maths.du.ac.in
# 8. lalit@maths.du.ac.in
# 9. lkumarvashisht@gmail.com
# 10. arvindpatelmath09@gmail.com
# 11. agaur@maths.du.ac.in
# 12. hksinghdu@gmail.com
# 13. rjain@maths.du.ac.in
# 14. sachinambariya@gmail.com
# 15. rkpanda@maths.du.ac.in
# 16. azothansanga26@yahoo.com
# 17. anupama.panigrahi@gmail.com
# 18. anuj.bshn@gmail.com
# 19. pratimarai5@gmail.com
# 20. surendraiitr8@gmail.com
# 21. randheernsit@gmail.com
# 22. sumitnagpal.du@gmail.com
# 23. mrigendra154@gmail.com
# 24. akumar@maths.du.ac.in
# 25. head@maths.du.ac.in

# %%
# Reprompting on the same data to prduce a different format output.
# RAG promt template
prompt_template = """You are an assistant and you are required to format the information a desired format. Use the following pieces context. The context contains a list of professors, their names, email addresses, designations etc. Understand the task carefully and and respond.
Context: {context} 
Task: Extract the names, designation, for each professor and return in this format
**Name** *emailID*

"""

# make the LLM read see the prompt, and analyse the retrieved document, and generate response

from langchain.chat_models import init_chat_model
llm = init_chat_model("gpt-4o-mini", model_provider="openai")

response = llm.invoke(prompt_template.format(
    context=full_doc,
    question=question))
    
from IPython.display import Markdown
Markdown(response.content)
# Out:
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here is the formatted information for each professor:
#
# **Prof. Tarun Kumar Das** *tarukd@gmail.com*
# **Prof. C.S. Lalitha** *cslalitha1@gmail.com*
# **Prof. Ruchi Das** *rdasmsu@gmail.com*
# **Prof. Vusala Ambethkar** *vambethkar@gmail.com, vambethkar@maths.du.ac.in*
# **Prof. Sachi Srivastava** *sachi_srivastava@yahoo.com; ssrivastava@maths.du.ac.in*
# **Prof. Lalit Kumar** *lalit@maths.du.ac.in, lkumarvashisht@gmail.com*
# **Prof. Arvind Patel** *arvindpatelmath09@gmail.com*
# **Dr. Atul Gaur** *agaur@maths.du.ac.in*
# **Dr. Hemant Kumar Singh** *hksinghdu@gmail.com*
# **Dr. Ranjana Jain** *rjain@maths.du.ac.in*
# **Dr. Sachin Kumar** *sachinambariya@gmail.com*
# **Dr. Ratikanta Panda** *rkpanda@maths.du.ac.in*
# **Dr. A. Zothansanga** *azothansanga26@yahoo.com*
# **Dr. Anupama Panigrahi** *anupama.panigrahi@gmail.com*
# **Dr. Anuj Bishnoi** *anuj.bshn@gmail.com*
# **Dr. Pratima Rai** *pratimarai5@gmail.com*
# **Dr. Surendra Kumar** *surendraiitr8@gmail.com*
# **Dr. Randheer Singh** *randheernsit@gmail.com*
# **Dr. Sumit Nagpal** *sumitnagpal.du@gmail.com*
# **Dr. Mrigendra Singh Kushwaha** *mrigendra154@gmail.com*
# **Prof. Ajay Kumar, FNASc** *akumar@maths.du.ac.in*

# %% [markdown]
# # Exercise: Try to extract something else from a different webpage
