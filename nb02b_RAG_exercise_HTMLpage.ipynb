# %% [markdown]
# # Example
#
# Lets extract information from webpages - using Unstructured
#
# https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#overview

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_unstructured import UnstructuredLoader

loader = UnstructuredLoader(web_url="https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages")
docs = loader.load()

for doc in docs:
    print(f"{doc}\n")
# Out:
# page_content='Open In Colab' metadata={'image_url': 'https://colab.research.google.com/assets/colab-badge.svg', 'link_texts': ['Open In Colab'], 'link_urls': ['https://colab.research.google.com/github/langchain-ai/langchain/blob/master/docs/docs/integrations/document_loaders/unstructured_file.ipynb'], 'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Image', 'element_id': '76f10732f139a03f24ecf55613a5116a'}
#
# page_content='Open on GitHub' metadata={'image_url': 'https://img.shields.io/badge/Open%20on%20GitHub-grey?logo=github&logoColor=white', 'link_texts': ['Open on GitHub'], 'link_urls': ['https://github.com/langchain-ai/langchain/blob/master/docs/docs/integrations/document_loaders/unstructured_file.ipynb'], 'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Image', 'element_id': '107161d68e7427a0c0fb47e44d7f9924'}
#
# page_content='Unstructured' metadata={'category_depth': 0, 'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': 'cd39606923c239d7f1857072b5b6478c'}
#
# page_content='This notebook covers how to use Unstructured document loader to load files of many types. Unstructured currently supports loading of text files, powerpoints, html, pdfs, images, and more.' metadata={'link_texts': ['document loader'], 'link_urls': ['https://python.langchain.com/docs/concepts/document_loaders'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '6fa0841e9d22a357628ce2ecb5626855'}
#
# page_content='Please see this guide for more instructions on setting up Unstructured locally, including setting up required system dependencies.' metadata={'link_texts': ['this guide'], 'link_urls': ['/docs/integrations/providers/unstructured/'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'd85131bc0b694180a3e22fc72b06d58a'}
#
# page_content='Overview​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#overview'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': '10c799289605c066d375cfa7356b6e11'}
#
# page_content='Integration details​' metadata={'category_depth': 2, 'link_texts': ['\u200b'], 'link_urls': ['#integration-details'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '10c799289605c066d375cfa7356b6e11', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': 'de09833a91a230c2fc64dae76f10214c'}
#
# page_content='Class Package Local Serializable JS support UnstructuredLoader langchain_unstructured ✅ ❌ ✅' metadata={'text_as_html': '<table><tr><td>Class</td><td>Package</td><td>Local</td><td>Serializable</td><td>JS support</td></tr><tr><td>UnstructuredLoader</td><td>langchain_unstructured</td><td>✅</td><td>❌</td><td>✅</td></tr></table>', 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'de09833a91a230c2fc64dae76f10214c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Table', 'element_id': '213415a36db1f5962a0062abe388d337'}
#
# page_content='Loader features​' metadata={'category_depth': 2, 'link_texts': ['\u200b'], 'link_urls': ['#loader-features'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '10c799289605c066d375cfa7356b6e11', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': 'e1a5c0a87d4da41661e70df519ddaf1a'}
#
# page_content='Source Document Lazy Loading Native Async Support UnstructuredLoader ✅ ❌' metadata={'text_as_html': '<table><tr><td>Source</td><td>Document Lazy Loading</td><td>Native Async Support</td></tr><tr><td>UnstructuredLoader</td><td>✅</td><td>❌</td></tr></table>', 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'e1a5c0a87d4da41661e70df519ddaf1a', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Table', 'element_id': '862157fae45e26b8bbde3c346e7e8ddf'}
#
# page_content='Setup​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#setup'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': '096cf57f56998a0cdbceb3a0b09bde4b'}
#
# page_content='Credentials​' metadata={'category_depth': 2, 'link_texts': ['\u200b'], 'link_urls': ['#credentials'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '096cf57f56998a0cdbceb3a0b09bde4b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': '0cc16fe8c9d65ffdc7b75f7ec3bf415d'}
#
# page_content='By default, langchain-unstructured installs a smaller footprint that requires offloading of the partitioning logic to the Unstructured API, which requires an API key. If you use the local installation, you do not need an API key. To get your API key, head over to this site and get an API key, and then set it in the cell below:' metadata={'link_texts': ['this site'], 'link_urls': ['https://unstructured.io'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '0cc16fe8c9d65ffdc7b75f7ec3bf415d', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'ab18735febe45ddf89c0e6dd65a1db4e'}
#
# page_content='import getpass
# import os
#
# if "UNSTRUCTURED_API_KEY" not in os.environ:
#     os.environ["UNSTRUCTURED_API_KEY"] = getpass.getpass(
#         "Enter your Unstructured API key: "
#     )' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '0cc16fe8c9d65ffdc7b75f7ec3bf415d', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '9a5a301422dbed3617f37726aa82adc3'}
#
# page_content='Installation​' metadata={'category_depth': 2, 'link_texts': ['\u200b'], 'link_urls': ['#installation'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '096cf57f56998a0cdbceb3a0b09bde4b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': 'e4cc001a8b099e7ff693cce31fe5a84b'}
#
# page_content='Normal Installation​' metadata={'category_depth': 3, 'link_texts': ['\u200b'], 'link_urls': ['#normal-installation'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'e4cc001a8b099e7ff693cce31fe5a84b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': 'bb72a64a168f3be4872ef9ddc8a86f1b'}
#
# page_content='The following packages are required to run the rest of this notebook.' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'bb72a64a168f3be4872ef9ddc8a86f1b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '4b29787cde8b90a092b0ded18f691243'}
#
# page_content='# Install package, compatible with API partitioning
# %pip install --upgrade --quiet langchain-unstructured unstructured-client unstructured "unstructured[pdf]" python-magic' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'bb72a64a168f3be4872ef9ddc8a86f1b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'a7e2adcd5dcaa9b1f8c06ee53078a997'}
#
# page_content='Installation for Local​' metadata={'category_depth': 3, 'link_texts': ['\u200b'], 'link_urls': ['#installation-for-local'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'e4cc001a8b099e7ff693cce31fe5a84b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': '31e7268849e353013707c2ca6c785ee7'}
#
# page_content='If you would like to run the partitioning logic locally, you will need to install a combination of system dependencies, as outlined in the Unstructured documentation here.' metadata={'link_texts': ['Unstructured documentation here'], 'link_urls': ['https://docs.unstructured.io/open-source/installation/full-installation'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '31e7268849e353013707c2ca6c785ee7', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '09b8cc0c372caa76eb6f35fad9d26d28'}
#
# page_content='For example, on Macs you can install the required dependencies with:' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '31e7268849e353013707c2ca6c785ee7', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '047d070a02ee8824f50945edcd0e4a57'}
#
# page_content='# base dependencies
# brew install libmagic poppler tesseract
#
# # If parsing xml / html documents:
# brew install libxml2 libxslt' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '31e7268849e353013707c2ca6c785ee7', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '9f26edae623c4908ddc38b22a104e161'}
#
# page_content='You can install the required pip dependencies needed for local with:' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '31e7268849e353013707c2ca6c785ee7', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '3fea5f6be0c8faf9602f72f7d075f3cb'}
#
# page_content='pip install "langchain-unstructured[local]"' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '31e7268849e353013707c2ca6c785ee7', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '587d04911ec98c2531a4bf94a62c3de1'}
#
# page_content='Initialization​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#initialization'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': 'bebbea960c26c9a5dc67ac45519c76db'}
#
# page_content='The UnstructuredLoader allows loading from a variety of different file types. To read all about the unstructured package please refer to their documentation/. In this example, we show loading from both a text file and a PDF file.' metadata={'link_texts': ['documentation'], 'link_urls': ['https://docs.unstructured.io/open-source/introduction/overview'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'bebbea960c26c9a5dc67ac45519c76db', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '9ca06cc97e990093d26a5b4d4412d08e'}
#
# page_content='from langchain_unstructured import UnstructuredLoader
#
# file_paths = [
#     "./example_data/layout-parser-paper.pdf",
#     "./example_data/state_of_the_union.txt",
# ]
#
#
# loader = UnstructuredLoader(file_paths)' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'bebbea960c26c9a5dc67ac45519c76db', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '9f17f7b958e0bb53f48b5b66d4dcfd98'}
#
# page_content='API Reference:UnstructuredLoader' metadata={'emphasized_text_contents': ['API Reference:'], 'emphasized_text_tags': ['b'], 'link_texts': ['UnstructuredLoader'], 'link_urls': ['https://python.langchain.com/api_reference/unstructured/document_loaders/langchain_unstructured.document_loaders.UnstructuredLoader.html'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'bebbea960c26c9a5dc67ac45519c76db', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '35b8b2f4e88cff62c80538535caa3159'}
#
# page_content='Load​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#load'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': 'a7f6be4b47eacbc72fcf28262ce008f0'}
#
# page_content='docs = loader.load()
#
# docs[0]' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'a7f6be4b47eacbc72fcf28262ce008f0', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'c37d0de2c56e0a8626282dd6aa3b2ac6'}
#
# page_content='INFO: pikepdf C++ to Python logger bridge initialized' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'a7f6be4b47eacbc72fcf28262ce008f0', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '98f3cbd104c7dcb1409bbe83940b805e'}
#
# page_content='Document(metadata={'source': './example_data/layout-parser-paper.pdf', 'coordinates': {'points': ((16.34, 213.36), (16.34, 253.36), (36.34, 253.36), (36.34, 213.36)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': './example_data', 'filename': 'layout-parser-paper.pdf', 'languages': ['eng'], 'last_modified': '2024-02-27T15:49:27', 'page_number': 1, 'filetype': 'application/pdf', 'category': 'UncategorizedText', 'element_id': 'd3ce55f220dfb75891b4394a18bcb973'}, page_content='1 2 0 2')' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'a7f6be4b47eacbc72fcf28262ce008f0', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': 'b9e090feb436ab21d3b4d8a12efc1742'}
#
# page_content='print(docs[0].metadata)' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'a7f6be4b47eacbc72fcf28262ce008f0', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '3e0bd7fb8a47c7a722064e5dfc95506e'}
#
# page_content='{'source': './example_data/layout-parser-paper.pdf', 'coordinates': {'points': ((16.34, 213.36), (16.34, 253.36), (36.34, 253.36), (36.34, 213.36)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': './example_data', 'filename': 'layout-parser-paper.pdf', 'languages': ['eng'], 'last_modified': '2024-02-27T15:49:27', 'page_number': 1, 'filetype': 'application/pdf', 'category': 'UncategorizedText', 'element_id': 'd3ce55f220dfb75891b4394a18bcb973'}' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'a7f6be4b47eacbc72fcf28262ce008f0', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '13a499c7a490895052b8766ddc8ca218'}
#
# page_content='Lazy Load​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#lazy-load'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': '84b14faa37d23974c7df3d511a338b74'}
#
# page_content='pages = []
# for doc in loader.lazy_load():
#     pages.append(doc)
#
# pages[0]' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '84b14faa37d23974c7df3d511a338b74', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '12956f3b306765346aee46e8e87e45d6'}
#
# page_content='Document(metadata={'source': './example_data/layout-parser-paper.pdf', 'coordinates': {'points': ((16.34, 213.36), (16.34, 253.36), (36.34, 253.36), (36.34, 213.36)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': './example_data', 'filename': 'layout-parser-paper.pdf', 'languages': ['eng'], 'last_modified': '2024-02-27T15:49:27', 'page_number': 1, 'filetype': 'application/pdf', 'category': 'UncategorizedText', 'element_id': 'd3ce55f220dfb75891b4394a18bcb973'}, page_content='1 2 0 2')' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '84b14faa37d23974c7df3d511a338b74', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '3ca511deda0dab0fa4b7661dc2938660'}
#
# page_content='Post Processing​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#post-processing'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': '55a52c5084e8cf20fa353dc04874ff62'}
#
# page_content='If you need to post process the unstructured elements after extraction, you can pass in a list of str -> str functions to the post_processors kwarg when you instantiate the UnstructuredLoader. This applies to other Unstructured loaders as well. Below is an example.' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '55a52c5084e8cf20fa353dc04874ff62', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'a6b01190f3d3abdbefc2b4c7dc328145'}
#
# page_content='from langchain_unstructured import UnstructuredLoader
# from unstructured.cleaners.core import clean_extra_whitespace
#
# loader = UnstructuredLoader(
#     "./example_data/layout-parser-paper.pdf",
#     post_processors=[clean_extra_whitespace],
# )
#
# docs = loader.load()
#
# docs[5:10]' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '55a52c5084e8cf20fa353dc04874ff62', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'bf19ca4055bf26859b7a1d9eeae839fc'}
#
# page_content='API Reference:UnstructuredLoader' metadata={'emphasized_text_contents': ['API Reference:'], 'emphasized_text_tags': ['b'], 'link_texts': ['UnstructuredLoader'], 'link_urls': ['https://python.langchain.com/api_reference/unstructured/document_loaders/langchain_unstructured.document_loaders.UnstructuredLoader.html'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '55a52c5084e8cf20fa353dc04874ff62', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': 'd4d6236a482d96146f7d7649c8bfc74d'}
#
# page_content='[Document(metadata={'source': './example_data/layout-parser-paper.pdf', 'coordinates': {'points': ((16.34, 393.9), (16.34, 560.0), (36.34, 560.0), (36.34, 393.9)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': './example_data', 'filename': 'layout-parser-paper.pdf', 'languages': ['eng'], 'last_modified': '2024-02-27T15:49:27', 'page_number': 1, 'parent_id': '89565df026a24279aaea20dc08cedbec', 'filetype': 'application/pdf', 'category': 'UncategorizedText', 'element_id': 'e9fa370aef7ee5c05744eb7bb7d9981b'}, page_content='2 v 8 4 3 5 1 . 3 0 1 2 : v i X r a'),
#  Document(metadata={'source': './example_data/layout-parser-paper.pdf', 'coordinates': {'points': ((157.62199999999999, 114.23496279999995), (157.62199999999999, 146.5141628), (457.7358962799999, 146.5141628), (457.7358962799999, 114.23496279999995)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': './example_data', 'filename': 'layout-parser-paper.pdf', 'languages': ['eng'], 'last_modified': '2024-02-27T15:49:27', 'page_number': 1, 'filetype': 'application/pdf', 'category': 'Title', 'element_id': 'bde0b230a1aa488e3ce837d33015181b'}, page_content='LayoutParser: A Uniﬁed Toolkit for Deep Learning Based Document Image Analysis'),
#  Document(metadata={'source': './example_data/layout-parser-paper.pdf', 'coordinates': {'points': ((134.809, 168.64029940800003), (134.809, 192.2517444), (480.5464199080001, 192.2517444), (480.5464199080001, 168.64029940800003)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': './example_data', 'filename': 'layout-parser-paper.pdf', 'languages': ['eng'], 'last_modified': '2024-02-27T15:49:27', 'page_number': 1, 'parent_id': 'bde0b230a1aa488e3ce837d33015181b', 'filetype': 'application/pdf', 'category': 'UncategorizedText', 'element_id': '54700f902899f0c8c90488fa8d825bce'}, page_content='Zejiang Shen1 ((cid:0)), Ruochen Zhang2, Melissa Dell3, Benjamin Charles Germain Lee4, Jacob Carlson3, and Weining Li5'),
#  Document(metadata={'source': './example_data/layout-parser-paper.pdf', 'coordinates': {'points': ((207.23000000000002, 202.57205439999996), (207.23000000000002, 311.8195408), (408.12676, 311.8195408), (408.12676, 202.57205439999996)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': './example_data', 'filename': 'layout-parser-paper.pdf', 'languages': ['eng'], 'last_modified': '2024-02-27T15:49:27', 'page_number': 1, 'parent_id': 'bde0b230a1aa488e3ce837d33015181b', 'filetype': 'application/pdf', 'category': 'UncategorizedText', 'element_id': 'b650f5867bad9bb4e30384282c79bcfe'}, page_content='1 Allen Institute for AI shannons@allenai.org 2 Brown University ruochen zhang@brown.edu 3 Harvard University {melissadell,jacob carlson}@fas.harvard.edu 4 University of Washington bcgl@cs.washington.edu 5 University of Waterloo w422li@uwaterloo.ca'),
#  Document(metadata={'source': './example_data/layout-parser-paper.pdf', 'coordinates': {'points': ((162.779, 338.45008160000003), (162.779, 566.8455408), (454.0372021523199, 566.8455408), (454.0372021523199, 338.45008160000003)), 'system': 'PixelSpace', 'layout_width': 612, 'layout_height': 792}, 'file_directory': './example_data', 'filename': 'layout-parser-paper.pdf', 'languages': ['eng'], 'last_modified': '2024-02-27T15:49:27', 'links': [{'text': ':// layout - parser . github . io', 'url': 'https://layout-parser.github.io', 'start_index': 1477}], 'page_number': 1, 'parent_id': 'bde0b230a1aa488e3ce837d33015181b', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'element_id': 'cfc957c94fe63c8fd7c7f4bcb56e75a7'}, page_content='Abstract. Recent advances in document image analysis (DIA) have been primarily driven by the application of neural networks. Ideally, research outcomes could be easily deployed in production and extended for further investigation. However, various factors like loosely organized codebases and sophisticated model conﬁgurations complicate the easy reuse of im- portant innovations by a wide audience. Though there have been on-going eﬀorts to improve reusability and simplify deep learning (DL) model development in disciplines like natural language processing and computer vision, none of them are optimized for challenges in the domain of DIA. This represents a major gap in the existing toolkit, as DIA is central to academic research across a wide range of disciplines in the social sciences and humanities. This paper introduces LayoutParser, an open-source library for streamlining the usage of DL in DIA research and applica- tions. The core LayoutParser library comes with a set of simple and intuitive interfaces for applying and customizing DL models for layout de- tection, character recognition, and many other document processing tasks. To promote extensibility, LayoutParser also incorporates a community platform for sharing both pre-trained models and full document digiti- zation pipelines. We demonstrate that LayoutParser is helpful for both lightweight and large-scale digitization pipelines in real-word use cases. The library is publicly available at https://layout-parser.github.io.')]' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '55a52c5084e8cf20fa353dc04874ff62', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '76249ac030df59ef8e18a956f712b3e8'}
#
# page_content='Unstructured API​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#unstructured-api'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': '226ac5c1422dfcb827defe083122b6e3'}
#
# page_content='If you want to get up and running with smaller packages and get the most up-to-date partitioning you can pip install unstructured-client and pip install langchain-unstructured. For more information about the UnstructuredLoader, refer to the Unstructured provider page.' metadata={'link_texts': ['Unstructured provider page'], 'link_urls': ['https://python.langchain.com/v0.1/docs/integrations/document_loaders/unstructured_file/'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '7399b9593b38ed4192818c44b808ff7b'}
#
# page_content='The loader will process your document using the hosted Unstructured serverless API when you pass in your api_key and set partition_via_api=True. You can generate a free Unstructured API key here.' metadata={'link_texts': ['here'], 'link_urls': ['https://unstructured.io/api-key/'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '0c696455891ec60ee19930b36c7d4015'}
#
# page_content='Check out the instructions here if you’d like to self-host the Unstructured API or run it locally.' metadata={'link_texts': ['here'], 'link_urls': ['https://github.com/Unstructured-IO/unstructured-api#dizzy-instructions-for-using-the-docker-image'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '4e0cd336eb664a2ce2423c2fcaa33b74'}
#
# page_content='from langchain_unstructured import UnstructuredLoader
#
# loader = UnstructuredLoader(
#     file_path="example_data/fake.docx",
#     api_key=os.getenv("UNSTRUCTURED_API_KEY"),
#     partition_via_api=True,
# )
#
# docs = loader.load()
# docs[0]' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'f1248c1d8cf4191a01b12145292c85bd'}
#
# page_content='API Reference:UnstructuredLoader' metadata={'emphasized_text_contents': ['API Reference:'], 'emphasized_text_tags': ['b'], 'link_texts': ['UnstructuredLoader'], 'link_urls': ['https://python.langchain.com/api_reference/unstructured/document_loaders/langchain_unstructured.document_loaders.UnstructuredLoader.html'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '85dd957e4673fedbd8d30014531e500d'}
#
# page_content='INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'bada1310775892274d9e95432dc679cd'}
#
# page_content='Document(metadata={'source': 'example_data/fake.docx', 'category_depth': 0, 'filename': 'fake.docx', 'languages': ['por', 'cat'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'Title', 'element_id': '56d531394823d81787d77a04462ed096'}, page_content='Lorem ipsum dolor sit amet.')' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '05d40b267545747d3249e0debb660cf9'}
#
# page_content='You can also batch multiple files through the Unstructured API in a single API using UnstructuredLoader.' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '9a9b3d14db2c4505ffc28d197359e997'}
#
# page_content='loader = UnstructuredLoader(
#     file_path=["example_data/fake.docx", "example_data/fake-email.eml"],
#     api_key=os.getenv("UNSTRUCTURED_API_KEY"),
#     partition_via_api=True,
# )
#
# docs = loader.load()
#
# print(docs[0].metadata["filename"], ": ", docs[0].page_content[:100])
# print(docs[-1].metadata["filename"], ": ", docs[-1].page_content[:100])' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '84469dee414e212d1a975fb97fb08e2d'}
#
# page_content='INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# ``````output
# fake.docx :  Lorem ipsum dolor sit amet.
# fake-email.eml :  Violets are blue' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '1c5109361728b12865de26755f374bbe'}
#
# page_content='Unstructured SDK Client​' metadata={'category_depth': 2, 'link_texts': ['\u200b'], 'link_urls': ['#unstructured-sdk-client'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '226ac5c1422dfcb827defe083122b6e3', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': 'f9be97a112bd890665c4de11cb082d3a'}
#
# page_content='Partitioning with the Unstructured API relies on the Unstructured SDK Client.' metadata={'link_texts': ['Unstructured SDK Client'], 'link_urls': ['https://docs.unstructured.io/api-reference/api-services/accessing-unstructured-api'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'f9be97a112bd890665c4de11cb082d3a', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '8c6c8d377d129cbb553a70be0a3b2343'}
#
# page_content='If you want to customize the client, you will have to pass an UnstructuredClient instance to the UnstructuredLoader. Below is an example showing how you can customize features of the client such as using your own requests.Session(), passing an alternative server_url, and customizing the RetryConfig object. For more information about customizing the client or what additional parameters the sdk client accepts, refer to the Unstructured Python SDK docs and the client section of the API Parameters docs. Note that all API Parameters should be passed to the UnstructuredLoader.' metadata={'link_texts': ['Unstructured Python SDK', 'API Parameters'], 'link_urls': ['https://docs.unstructured.io/api-reference/api-services/sdk-python', 'https://docs.unstructured.io/api-reference/api-services/api-parameters'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'f9be97a112bd890665c4de11cb082d3a', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'f157205098e73a32e73077a846198d27'}
#
# page_content='Warning: The example below may not use the latest version of the UnstructuredClient and there could be breaking changes in future releases. For the latest examples, refer to the Unstructured Python SDK docs.' metadata={'emphasized_text_contents': ['Warning:'], 'emphasized_text_tags': ['b'], 'link_texts': ['Unstructured Python SDK'], 'link_urls': ['https://docs.unstructured.io/api-reference/api-services/sdk-python'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'f9be97a112bd890665c4de11cb082d3a', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '3a169db9ed70aad134aed51d405aff36'}
#
# page_content='import requests
# from langchain_unstructured import UnstructuredLoader
# from unstructured_client import UnstructuredClient
# from unstructured_client.utils import BackoffStrategy, RetryConfig
#
# client = UnstructuredClient(
#     api_key_auth=os.getenv(
#         "UNSTRUCTURED_API_KEY"
#     ),  # Note: the client API param is "api_key_auth" instead of "api_key"
#     client=requests.Session(),  # Define your own requests session
#     server_url="https://api.unstructuredapp.io/general/v0/general",  # Define your own api url
#     retry_config=RetryConfig(
#         strategy="backoff",
#         retry_connection_errors=True,
#         backoff=BackoffStrategy(
#             initial_interval=500,
#             max_interval=60000,
#             exponent=1.5,
#             max_elapsed_time=900000,
#         ),
#     ),  # Define your own retry config
# )
#
# loader = UnstructuredLoader(
#     "./example_data/layout-parser-paper.pdf",
#     partition_via_api=True,
#     client=client,
#     split_pdf_page=True,
#     split_pdf_page_range=[1, 10],
# )
#
# docs = loader.load()
#
# print(docs[0].metadata["filename"], ": ", docs[0].page_content[:100])' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'f9be97a112bd890665c4de11cb082d3a', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'bd22e564481040f10feecda8ac54457b'}
#
# page_content='API Reference:UnstructuredLoader' metadata={'emphasized_text_contents': ['API Reference:'], 'emphasized_text_tags': ['b'], 'link_texts': ['UnstructuredLoader'], 'link_urls': ['https://python.langchain.com/api_reference/unstructured/document_loaders/langchain_unstructured.document_loaders.UnstructuredLoader.html'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'f9be97a112bd890665c4de11cb082d3a', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '74c6642b7026c931c3f785f739f54de4'}
#
# page_content='INFO: Preparing to split document for partition.
# INFO: Concurrency level set to 5
# INFO: Splitting pages 1 to 10 (10 total)
# INFO: Determined optimal split size of 2 pages.
# INFO: Partitioning 5 files with 2 page(s) each.
# INFO: Partitioning set #1 (pages 1-2).
# INFO: Partitioning set #2 (pages 3-4).
# INFO: Partitioning set #3 (pages 5-6).
# INFO: Partitioning set #4 (pages 7-8).
# INFO: Partitioning set #5 (pages 9-10).
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: Successfully partitioned set #1, elements added to the final result.
# INFO: Successfully partitioned set #2, elements added to the final result.
# INFO: Successfully partitioned set #3, elements added to the final result.
# INFO: Successfully partitioned set #4, elements added to the final result.
# INFO: Successfully partitioned set #5, elements added to the final result.
# INFO: Successfully partitioned the document.
# ``````output
# layout-parser-paper.pdf :  LayoutParser: A Uniﬁed Toolkit for Deep Learning Based Document Image Analysis' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'f9be97a112bd890665c4de11cb082d3a', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '4818fb316d9ebaad4a22a8d76215b8f3'}
#
# page_content='Chunking​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#chunking'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': 'dbbea7b4b89a8ae623f978d6c474cb6b'}
#
# page_content='The UnstructuredLoader does not support mode as parameter for grouping text like the older loader UnstructuredFileLoader and others did. It instead supports "chunking". Chunking in unstructured differs from other chunking mechanisms you may be familiar with that form chunks based on plain-text features--character sequences like "\n\n" or "\n" that might indicate a paragraph boundary or list-item boundary. Instead, all documents are split using specific knowledge about each document format to partition the document into semantic units (document elements) and we only need to resort to text-splitting when a single element exceeds the desired maximum chunk size. In general, chunking combines consecutive elements to form chunks as large as possible without exceeding the maximum chunk size. Chunking produces a sequence of CompositeElement, Table, or TableChunk elements. Each “chunk” is an instance of one of these three types.' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'dbbea7b4b89a8ae623f978d6c474cb6b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '1c764f32dce10e84d6b9ce077369d722'}
#
# page_content='See this page for more details about chunking options, but to reproduce the same behavior as mode="single", you can set chunking_strategy="basic", max_characters=<some-really-big-number>, and include_orig_elements=False.' metadata={'link_texts': ['page'], 'link_urls': ['https://docs.unstructured.io/open-source/core-functionality/chunking'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'dbbea7b4b89a8ae623f978d6c474cb6b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '8bc79754e87ee0d4a4ef36172fb0389c'}
#
# page_content='from langchain_unstructured import UnstructuredLoader
#
# loader = UnstructuredLoader(
#     "./example_data/layout-parser-paper.pdf",
#     chunking_strategy="basic",
#     max_characters=1000000,
#     include_orig_elements=False,
# )
#
# docs = loader.load()
#
# print("Number of LangChain documents:", len(docs))
# print("Length of text in the document:", len(docs[0].page_content))' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'dbbea7b4b89a8ae623f978d6c474cb6b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '6d6d0fc283676b7f3f15c739b2e1caf1'}
#
# page_content='API Reference:UnstructuredLoader' metadata={'emphasized_text_contents': ['API Reference:'], 'emphasized_text_tags': ['b'], 'link_texts': ['UnstructuredLoader'], 'link_urls': ['https://python.langchain.com/api_reference/unstructured/document_loaders/langchain_unstructured.document_loaders.UnstructuredLoader.html'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'dbbea7b4b89a8ae623f978d6c474cb6b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': 'ddd28a14a7966f64cd798862c6d1511c'}
#
# page_content='Number of LangChain documents: 1
# Length of text in the document: 42772' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'dbbea7b4b89a8ae623f978d6c474cb6b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '7b6fb7e7a057d35e78bdc4c7faa55b0d'}
#
# page_content='Loading web pages​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#loading-web-pages'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': '9680a035b1ba1c007006cc97101896f2'}
#
# page_content='UnstructuredLoader accepts a web_url kwarg when run locally that populates the url parameter of the underlying Unstructured partition. This allows for the parsing of remotely hosted documents, such as HTML web pages.' metadata={'link_texts': ['partition'], 'link_urls': ['https://docs.unstructured.io/open-source/core-functionality/partitioning'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '9680a035b1ba1c007006cc97101896f2', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'a55fc7f24507f172c1cb3621be3a6b61'}
#
# page_content='Example usage:' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '9680a035b1ba1c007006cc97101896f2', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '48dc13159d5f0c836b088ac5fde0c8f7'}
#
# page_content='from langchain_unstructured import UnstructuredLoader
#
# loader = UnstructuredLoader(web_url="https://www.example.com")
# docs = loader.load()
#
# for doc in docs:
#     print(f"{doc}\n")' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '9680a035b1ba1c007006cc97101896f2', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '334171cd3758e1813605c725d03ddd23'}
#
# page_content='API Reference:UnstructuredLoader' metadata={'emphasized_text_contents': ['API Reference:'], 'emphasized_text_tags': ['b'], 'link_texts': ['UnstructuredLoader'], 'link_urls': ['https://python.langchain.com/api_reference/unstructured/document_loaders/langchain_unstructured.document_loaders.UnstructuredLoader.html'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '9680a035b1ba1c007006cc97101896f2', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '271dc2dc27166d787f265b63b287bec2'}
#
# page_content='page_content='Example Domain' metadata={'category_depth': 0, 'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://www.example.com', 'category': 'Title', 'element_id': 'fdaa78d856f9d143aeeed85bf23f58f8'}
#
# page_content='This domain is for use in illustrative examples in documents. You may use this domain in literature without prior coordination or asking for permission.' metadata={'languages': ['eng'], 'parent_id': 'fdaa78d856f9d143aeeed85bf23f58f8', 'filetype': 'text/html', 'url': 'https://www.example.com', 'category': 'NarrativeText', 'element_id': '3652b8458b0688639f973fe36253c992'}
#
# page_content='More information...' metadata={'category_depth': 0, 'link_texts': ['More information...'], 'link_urls': ['https://www.iana.org/domains/example'], 'languages': ['eng'], 'filetype': 'text/html', 'url': 'https://www.example.com', 'category': 'Title', 'element_id': '793ab98565d6f6d6f3a6d614e3ace2a9'}' metadata={'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '9680a035b1ba1c007006cc97101896f2', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': '23b334213a417f4fa35e734d7c0dc5f6'}
#
# page_content='API reference​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#api-reference'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': 'd9bceaa7f753aaf91fd3dc352aba49b7'}
#
# page_content='For detailed documentation of all UnstructuredLoader features and configurations head to the API reference: https://python.langchain.com/api_reference/unstructured/document_loaders/langchain_unstructured.document_loaders.UnstructuredLoader.html' metadata={'link_texts': ['https://python.langchain.com/api_reference/unstructured/document_loaders/langchain_unstructured.document_loaders.UnstructuredLoader.html'], 'link_urls': ['https://python.langchain.com/api_reference/unstructured/document_loaders/langchain_unstructured.document_loaders.UnstructuredLoader.html'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'd9bceaa7f753aaf91fd3dc352aba49b7', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'NarrativeText', 'element_id': 'cd0c2a1e6fc050e8795919bc86ae63f9'}
#
# page_content='Related​' metadata={'category_depth': 1, 'link_texts': ['\u200b'], 'link_urls': ['#related'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'cd39606923c239d7f1857072b5b6478c', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': '11db86c7eb767d3bc260c0df14002345'}
#
# page_content='Document loader conceptual guide' metadata={'category_depth': 1, 'link_texts': ['conceptual guide'], 'link_urls': ['/docs/concepts/document_loaders/'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '11db86c7eb767d3bc260c0df14002345', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '0b742831c566ead00116436d979e4df1'}
#
# page_content='Document loader how-to guides' metadata={'category_depth': 1, 'link_texts': ['how-to guides'], 'link_urls': ['/docs/how_to/#document-loaders'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '11db86c7eb767d3bc260c0df14002345', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': 'b217b0fdae169ec71e305ab84d3160fb'}
#
# page_content='Edit this page' metadata={'link_texts': ['Edit this page'], 'link_urls': ['https://github.com/langchain-ai/langchain/edit/master/docs/docs/integrations/document_loaders/unstructured_file.ipynb'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '11db86c7eb767d3bc260c0df14002345', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'UncategorizedText', 'element_id': '49c38f02cad08b471e2fcc5f8340f3db'}
#
# page_content='Was this page helpful?' metadata={'category_depth': 3, 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '11db86c7eb767d3bc260c0df14002345', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'Title', 'element_id': '6c87f140d3babd5e77a8e0e3cee8c29e'}
#
# page_content='Overview' metadata={'category_depth': 1, 'link_texts': ['Overview'], 'link_urls': ['#overview'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '00a2e482ae55b89f74afc6a67cb07bb4'}
#
# page_content='Integration details' metadata={'category_depth': 2, 'link_texts': ['Integration details'], 'link_urls': ['#integration-details'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '00a2e482ae55b89f74afc6a67cb07bb4', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '7f177b1b6a1921f61c916922e369e2f9'}
#
# page_content='Loader features' metadata={'category_depth': 2, 'link_texts': ['Loader features'], 'link_urls': ['#loader-features'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '00a2e482ae55b89f74afc6a67cb07bb4', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': 'bde9d2e88b9af676272c5c3c71b070a4'}
#
# page_content='Setup' metadata={'category_depth': 1, 'link_texts': ['Setup'], 'link_urls': ['#setup'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '051fe9a4a55356382704054d2413f735'}
#
# page_content='Credentials' metadata={'category_depth': 2, 'link_texts': ['Credentials'], 'link_urls': ['#credentials'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '051fe9a4a55356382704054d2413f735', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': 'ca4bc80b3f908510f385f37a94b8294a'}
#
# page_content='Installation' metadata={'category_depth': 2, 'link_texts': ['Installation'], 'link_urls': ['#installation'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '051fe9a4a55356382704054d2413f735', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '6b7e7a799c7feb902742b9a3b4683d84'}
#
# page_content='Initialization' metadata={'category_depth': 1, 'link_texts': ['Initialization'], 'link_urls': ['#initialization'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '2c8b8b62cc09f65acfb0b7348149af56'}
#
# page_content='Load' metadata={'category_depth': 1, 'link_texts': ['Load'], 'link_urls': ['#load'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '153f7aede7ac81e36a1fb8c5433832b1'}
#
# page_content='Lazy Load' metadata={'category_depth': 1, 'link_texts': ['Lazy Load'], 'link_urls': ['#lazy-load'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '1a5edf01c39aa0d364332ee684b4712a'}
#
# page_content='Post Processing' metadata={'category_depth': 1, 'link_texts': ['Post Processing'], 'link_urls': ['#post-processing'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '0f2d1990ac426fc4b454f9edd9ef9df7'}
#
# page_content='Unstructured API' metadata={'category_depth': 1, 'link_texts': ['Unstructured API'], 'link_urls': ['#unstructured-api'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': 'd452a0cb77d1e14059821709a166a67b'}
#
# page_content='Unstructured SDK Client' metadata={'category_depth': 2, 'link_texts': ['Unstructured SDK Client'], 'link_urls': ['#unstructured-sdk-client'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': 'd452a0cb77d1e14059821709a166a67b', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '059689b6c041ea5e8779e26e302fe439'}
#
# page_content='Chunking' metadata={'category_depth': 1, 'link_texts': ['Chunking'], 'link_urls': ['#chunking'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '5df59345cf8ae72a404373aee6aa64cc'}
#
# page_content='Loading web pages' metadata={'category_depth': 1, 'link_texts': ['Loading web pages'], 'link_urls': ['#loading-web-pages'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': 'd71a62cae825cd2da3ab4042d5257e16'}
#
# page_content='API reference' metadata={'category_depth': 1, 'link_texts': ['API reference'], 'link_urls': ['#api-reference'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': 'a205fce4a186eb56a710fe565856142a'}
#
# page_content='Related' metadata={'category_depth': 1, 'link_texts': ['Related'], 'link_urls': ['#related'], 'languages': ['eng'], 'filetype': 'text/html', 'parent_id': '6c87f140d3babd5e77a8e0e3cee8c29e', 'url': 'https://python.langchain.com/docs/integrations/document_loaders/unstructured_file/#loading-web-pages', 'category': 'ListItem', 'element_id': '7d833e11e15a6041e796df38586b644a'}

# %%
# Split document into small chunks
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # chunk size (characters)
    chunk_overlap=200,  # chunk overlap (characters)
    add_start_index=True,  # track index in original document
)
all_splits = text_splitter.split_documents(docs)

# get embedding models, create vectorstore, store chunks in vectorstore

from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

from langchain_core.vectorstores import InMemoryVectorStore
vector_store = InMemoryVectorStore(embeddings)

# adding documents in vectorstores
document_ids = vector_store.add_documents(documents=all_splits)
# Out:
# INFO: HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
question = "Show me an example of a python code of how to load a web-page in langchain."

# %%
# extract chunks which matches with your query
search_results = vector_store.similarity_search_with_score(question, k=10)

# conbine text from differrent chunks into one long string
doc_content = "\n\n".join(doc.page_content for (doc,score) in search_results)

# RAG promt template
prompt_template = """You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
Question: {question} 
Context: {context} 
Answer:"""

# make the LLM read see the prompt, and analyse the retrieved document, and generate response

from langchain.chat_models import init_chat_model
llm = init_chat_model("gpt-4o-mini", model_provider="openai")

response = llm.invoke(prompt_template.format(
    context=doc_content,
    question=question))
    
print(response.content)
# Out:
# INFO: HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# To load a web page using LangChain, you can use the following Python code:
#
# ```python
# from langchain_unstructured import UnstructuredLoader
#
# loader = UnstructuredLoader(web_url="https://www.example.com")
# docs = loader.load()
#
# for doc in docs:
#     print(f"{doc}\n")
# ```
#
# Make sure to install the required package with `pip install "langchain-unstructured[local]"`.

# %%
from IPython.display import Markdown
Markdown(response.content)
# Out:
# To load a web page using LangChain, you can use the following Python code:
#
# ```python
# from langchain_unstructured import UnstructuredLoader
#
# loader = UnstructuredLoader(web_url="https://www.example.com")
# docs = loader.load()
#
# for doc in docs:
#     print(f"{doc}\n")
# ```
#
# Make sure to install the required package with `pip install "langchain-unstructured[local]"`.

# %% [markdown]
# # Exercise: Repeat this exercise with
#
# - different question
# - different url
# - different llm model
# - different embedding model
# - different vectorstore
