# %% [markdown]
# # Langraphs basics
#
# Graphs, States

# %% [markdown]
# ## graphs: a network of python functions
#
# ## nodes: python functions
#
# What does these  nodes(function) do? Updates `states`
#
# ### `States`: Basically a dictionary which maintain chat history

# %% [markdown]
# ---
#
# ### Example Graph
#
# [hello_graph.py](.\studio\hello_graph.py)
#
#
# ![image.png](attachment:image.png)
#
# ---

# %% [markdown]
# ### Exercise: Run this graph in langsmith studio

# %% [markdown]
# ## Example graph with conditional edges
#
# [hello_graph_2](.\studio\hello_graph_2.py)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Langraphs based Chatbots

# %% [markdown]
# ## Example: Simple chatbot
#
# [simple chatbot](.\studio\simple_chatbot_01.py)

# %% [markdown]
# ## Example: Improved Chatbot. Maintaines running summary, and deletes old messages.
#
# Question: What is the benefit of deleteing old messages?
# Ans: Reduces the number of tokens sent to llms and hence saves money
#
# [Improved simple chatbot](.\studio\simple_chatbot_02.py)
